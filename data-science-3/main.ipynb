# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
#import statsmodels.api as sm
#import statsmodels.stats as st
from sklearn.decomposition import PCA

#from loguru import logger

# %%
# Algumas configurações para o matplotlib.
#%matplotlib inline

from IPython.core.pylabtools import figsize


figsize(12, 8)

sns.set()

# %%
fifa = pd.read_csv("fifa.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    fifa.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
fifa.head(100)
# Out:
#     Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0    31       94         94      84.0       95.0             70.0
# 1    33       94         94      84.0       94.0             89.0
# 2    26       92         93      79.0       87.0             62.0
# 3    27       91         93      17.0       13.0             21.0
# 4    27       91         92      93.0       82.0             55.0
# ..  ...      ...        ...       ...        ...              ...
# 95   29       85         85      69.0       34.0             85.0
# 96   31       85         85      76.0       75.0             82.0
# 97   29       85         85      83.0       79.0             80.0
# 98   32       85         85      63.0       89.0             84.0
# 99   31       85         85      72.0       72.0             76.0
#
#     ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 0           90.0     86.0       97.0   93.0  ...       75.0       96.0
# ...

# %%
aux = pd.DataFrame({'colunas' : fifa.columns,
                   'tipo' : fifa.dtypes,
                   'missing' : fifa.isna().sum(),
                   'size' : fifa.shape[0],
                   'unicos' : fifa.nunique()})
aux
# Out:
#                          colunas     tipo  missing   size  unicos
# Age                          Age    int64        0  18207      29
# Overall                  Overall    int64        0  18207      48
# Potential              Potential    int64        0  18207      47
# Crossing                Crossing  float64       48  18207      89
# Finishing              Finishing  float64       48  18207      93
# HeadingAccuracy  HeadingAccuracy  float64       48  18207      91
# ShortPassing        ShortPassing  float64       48  18207      85
# Volleys                  Volleys  float64       48  18207      87
# Dribbling              Dribbling  float64       48  18207      94
# Curve                      Curve  float64       48  18207      89
# FKAccuracy            FKAccuracy  float64       48  18207      90
# LongPassing          LongPassing  float64       48  18207      84
# BallControl          BallControl  float64       48  18207      90
# ...

# %%
fifa.dropna(inplace = True)
fifa.corr().round(2)
# Out:
#                   Age  Overall  Potential  Crossing  Finishing  \
# Age              1.00     0.45      -0.25      0.13       0.07
# Overall          0.45     1.00       0.66      0.39       0.33
# Potential       -0.25     0.66       1.00      0.25       0.24
# Crossing         0.13     0.39       0.25      1.00       0.66
# Finishing        0.07     0.33       0.24      0.66       1.00
# HeadingAccuracy  0.15     0.34       0.20      0.47       0.47
# ShortPassing     0.13     0.50       0.37      0.81       0.66
# Volleys          0.14     0.39       0.25      0.69       0.88
# Dribbling        0.01     0.37       0.32      0.86       0.82
# Curve            0.14     0.42       0.28      0.83       0.76
# FKAccuracy       0.19     0.40       0.23      0.76       0.70
# LongPassing      0.18     0.48       0.32      0.76       0.51
# BallControl      0.08     0.46       0.35      0.84       0.79
# Acceleration    -0.16     0.20       0.23      0.67       0.61
# ...

# %%
sns.heatmap(fifa.corr().round(2),  annot=True, annot_kws={"size": 7})

# %%
fifa_standardize = ((fifa - fifa.mean())/fifa.std())
fifa_standardize
# Out:
#             Age   Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0      1.258406  4.013254   3.697314  1.865870   2.532497         1.018524
# 1      1.686619  4.013254   3.697314  1.865870   2.481283         2.111740
# 2      0.187872  3.724011   3.534299  1.593606   2.122783         0.558222
# 3      0.401979  3.579390   3.534299 -1.782468  -1.667070        -1.800823
# 4      0.401979  3.579390   3.371284  2.355946   1.866712         0.155459
# ...         ...       ...        ...       ...        ...              ...
# 18202 -1.310875 -2.783945  -1.030110 -0.856770  -0.386714        -0.707607
# 18203 -1.310875 -2.783945  -1.356139 -1.455751   0.330285        -0.017155
# 18204 -1.953195 -2.783945  -0.704081 -1.346846  -0.284286        -0.362381
# 18205 -1.739088 -2.783945  -0.867095 -0.312242   0.227857        -0.765145
# 18206 -1.953195 -2.928567  -0.867095 -0.475601  -0.591571        -0.362381
#
# ...

# %%
sns.heatmap(fifa_standardize.corr().round(2),  annot=True, annot_kws={"size": 7})

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
fifa.dropna(inplace = True)
fifa_standardize = ((fifa - fifa.mean())/fifa.std())
pca = PCA(n_components = 1)
first_principal_component = pca.fit_transform(fifa_standardize)
evr = pca.explained_variance_ratio_
float(round(evr[0],3))
# Out:
# 0.517

# %%
def q1():
    fifa.dropna(inplace = True)
    #fifa_standardize = ((fifa - fifa.mean())/fifa.std())
    pca = PCA(n_components = 1)
    first_principal_component = pca.fit(fifa)
    evr = pca.explained_variance_ratio_
    return float(round(evr[0],3))

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
pca_components = PCA(0.95)
n_components = pca_components.fit_transform(fifa_standardize)
int(n_components.shape[1])
# Out:
# 16

# %%
def q2():
    pca_components = PCA(0.95)
    n_components = pca_components.fit_transform(fifa)
    return int(n_components.shape[1])

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %%
pca_3 = PCA(n_components = 2).fit(fifa_standardize)
result = pca_3.components_.dot(x).round(3)
tuple(result)
# Out:
# (182.581, -14.139)

# %%
def q3():
    pca_3 = PCA(n_components = 2).fit(fifa)
    result = pca_3.components_.dot(x).round(3)
    return tuple(result)

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import RFE

# %%
fifa.dropna(inplace = True)
fifa_x = fifa.drop('Overall',1)
fifa_y = fifa['Overall']
X_train, X_test, y_train, y_test = train_test_split(fifa_x,  fifa_y, test_size = 0.2)
sc = StandardScaler()
X_train = ((X_train - X_train.mean())/X_train.std())
X_test = ((X_test - X_test.mean())/X_test.std())
linear = LinearRegression()
model = linear.fit(X_train, y_train)
rfe = RFE(linear, 5)
rfe_fit = rfe.fit(X_train, y_train)

# %%
resultado = pd.DataFrame({'colunas': X_train.columns, 
                          'bool':rfe_fit.get_support(),
                          'coeficientes': pd.Series(linear.coef_)})

# %%
resultado_coef = resultado[resultado['bool'] == True]
resultado_final = list(resultado_coef['colunas'])
resultado_final
# Out:
# ['Age', 'Potential', 'BallControl', 'Reactions', 'GKReflexes']

# %%
def q4():
    fifa.dropna(inplace = True)
    fifa_x = fifa.drop('Overall',1)
    fifa_y = fifa['Overall']
    X_train, X_test, y_train, y_test = train_test_split(fifa_x,  fifa_y, test_size = 0.2)
    sc = StandardScaler()
    X_train = ((X_train - X_train.mean())/X_train.std())
    X_test = ((X_test - X_test.mean())/X_test.std())
    linear = LinearRegression()
    model = linear.fit(X_train, y_train)
    rfe = RFE(linear, 5)
    rfe_fit = rfe.fit(X_train, y_train)
    resultado = pd.DataFrame({'colunas': X_train.columns, 
                              'bool':rfe_fit.get_support(),
                              'coeficientes': pd.Series(linear.coef_)})
    resultado_coef = resultado[resultado['bool'] == True]
    resultado_final = list(resultado_coef['colunas'])
    return resultado_final
